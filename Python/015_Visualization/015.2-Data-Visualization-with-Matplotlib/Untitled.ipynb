# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.linspace(0,5,11)

# %%
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y,'r')
plt.xlabel('X Axis')
plt.ylabel('Y label')
plt.title('Title Here')
# Out:
# Text(0.5,1,'Title Here')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'b--')
plt.subplot(1,2,2)
plt.plot(y,x,'r')

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1,0.8,0.8])

axes.plot(x,y,'r')
axes.set_xlabel('X Axis')
axes.set_ylabel('Y Axis')
axes.set_title('Title')
# Out:
# Text(0.5,1,'Title')

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.1,0.8,0.8])
axes2 = fig.add_axes([0.2, 0.5,0.4,0.3])

#Larger Plot
axes1.plot(x,y,'r')
axes1.set_xlabel('X Axis')
axes1.set_ylabel('Y Axis')
axes1.set_title('Title')

#Smaller PLot
axes2.plot(x,y,'b')
axes2.set_xlabel('X Axis')
axes2.set_ylabel('Y Axis')
axes2.set_title('Title')
# Out:
# Text(0.5,1,'Title')

# %%
fig, axes = plt.subplots()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000000009647320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000096DE908>],
#       dtype=object)

# %%
for item in axes:
    item.plot(x,y,'b')

fig
plt.tight_layout()
fig

# %%
fig = plt.figure(figsize=(8,4))

# %%
fig, axes = plt.subplots(figsize=(12,3))

axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title')
# Out:
# Text(0.5,1,'title')

# %%
fig.savefig('file.png', dpi=200)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y,'g--',label='First Plot')
ax.plot(y,x, label='Second Plot')
ax.legend(loc=0)
